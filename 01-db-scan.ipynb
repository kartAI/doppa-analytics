# %%
from src.persistence import create_duckdb_context
from src.utils import (
    create_hive_virtual_file_path, shapiro_wilk, linechart, mann_whitney_u_test, plot_barchart_per_core,
    linechart_per_iteration, linechart_per_iteration_timeseries, bytes_to_mb,
    heatmap_cpu_percent_per_iteration
)

# %%
db_context = create_duckdb_context()

# %%
is_development = True

RUN_ID = "2026-02-27-ABCDEF" if is_development else "2026-02-26-TSPSAS"
CONTAINER = "dev-benchmarks" if is_development else "benchmarks"

# %%
query_id_cn = "db-scan-blob-storage"
query_id_traditional = "db-scan-postgis"

# %% [markdown]
# ## Read data from Blob Storage

# %%
hive_path_cn = create_hive_virtual_file_path(
    container=CONTAINER,
    query_id=query_id_cn,
    run_id=RUN_ID,
    iteration=-1,
    file_name="*.parquet"
)

hive_path_traditional = create_hive_virtual_file_path(
    container=CONTAINER,
    query_id=query_id_traditional,
    run_id=RUN_ID,
    iteration=-1,
    file_name="*.parquet"
)

# %%
cn_df = db_context.execute(f"SELECT * FROM read_parquet('{hive_path_cn}')").fetchdf()
print("Shape:", cn_df.shape)
cn_df.head()
# Out:
# Shape: (562, 16)
#    elapsed_time  delta_time  delta_process_cpu_time  process_cpu_percentage  \
# 0      0.013498    0.013498                 0.00000                     0.0
# 1      0.028911    0.015414                 0.00000                     0.0
# 2      0.043819    0.014908                 0.00000                     0.0
# 3      0.059432    0.015613                 0.00000                     0.0
# 4      0.075419    0.015987                 0.09375                   579.2
#
#          rss                                             core_1  \
# 0  203829248  {'idle': 0.0, 'iowait': 0.0, 'percent': 100.0,...
# 1  203866112  {'idle': 0.015625, 'iowait': 0.0, 'percent': 0...
# 2  204132352  {'idle': 0.015625, 'iowait': 0.0, 'percent': 1...
# 3  205369344  {'idle': 0.015625, 'iowait': 0.0, 'percent': 1...
# 4  206811136  {'idle': 0.03125, 'iowait': 0.0, 'percent': 0....
#
#                                               core_2  \
# 0  {'idle': 0.0, 'iowait': 0.0, 'percent': 100.0,...
# 1  {'idle': 0.015625, 'iowait': 0.0, 'percent': 0...
# 2  {'idle': 0.015625, 'iowait': 0.0, 'percent': 1...
# 3  {'idle': 0.015625, 'iowait': 0.0, 'percent': 1...
# 4  {'idle': 0.03125, 'iowait': 0.0, 'percent': 0....
#
#                                               core_3  \
# 0  {'idle': 0.015625, 'iowait': 0.0, 'percent': 0...
# 1  {'idle': 0.03125, 'iowait': 0.0, 'percent': 0....
# 2  {'idle': 0.03125, 'iowait': 0.0, 'percent': 10...
# 3  {'idle': 0.03125, 'iowait': 0.0, 'percent': 10...
# 4  {'idle': 0.03125, 'iowait': 0.0, 'percent': 10...
#
#                                               core_4  \
# 0  {'idle': 0.015625, 'iowait': 0.0, 'percent': 0...
# 1  {'idle': 0.03125, 'iowait': 0.0, 'percent': 0....
# 2  {'idle': 0.03125, 'iowait': 0.0, 'percent': 10...
# 3  {'idle': 0.03125, 'iowait': 0.0, 'percent': 10...
# 4  {'idle': 0.03125, 'iowait': 0.0, 'percent': 10...
#
#                                               core_5  \
# 0  {'idle': 0.015625, 'iowait': 0.0, 'percent': 0...
# 1  {'idle': 0.015625, 'iowait': 0.0, 'percent': 1...
# 2  {'idle': 0.015625, 'iowait': 0.0, 'percent': 1...
# 3  {'idle': 0.015625, 'iowait': 0.0, 'percent': 1...
# 4  {'idle': 0.015625, 'iowait': 0.0, 'percent': 1...
#
#                                               core_6  \
# 0  {'idle': 0.015625, 'iowait': 0.0, 'percent': 0...
# 1  {'idle': 0.015625, 'iowait': 0.0, 'percent': 1...
# 2  {'idle': 0.015625, 'iowait': 0.0, 'percent': 1...
# 3  {'idle': 0.015625, 'iowait': 0.0, 'percent': 1...
# 4  {'idle': 0.015625, 'iowait': 0.0, 'percent': 1...
#
#                                               core_7  \
# 0  {'idle': 0.015625, 'iowait': 0.0, 'percent': 0...
# 1  {'idle': 0.03125, 'iowait': 0.0, 'percent': 0....
# 2  {'idle': 0.03125, 'iowait': 0.0, 'percent': 10...
# 3  {'idle': 0.03125, 'iowait': 0.0, 'percent': 10...
# 4  {'idle': 0.03125, 'iowait': 0.0, 'percent': 10...
#
#                                               core_8  iteration  \
# 0  {'idle': 0.015625, 'iowait': 0.0, 'percent': 0...          1
# 1  {'idle': 0.03125, 'iowait': 0.0, 'percent': 0....          1
# 2  {'idle': 0.03125, 'iowait': 0.0, 'percent': 10...          1
# 3  {'idle': 0.03125, 'iowait': 0.0, 'percent': 10...          1
# 4  {'idle': 0.03125, 'iowait': 0.0, 'percent': 10...          1
#
#                query_id             run_id
# 0  db-scan-blob-storage  2026-02-27-ABCDEF
# 1  db-scan-blob-storage  2026-02-27-ABCDEF
# 2  db-scan-blob-storage  2026-02-27-ABCDEF
# 3  db-scan-blob-storage  2026-02-27-ABCDEF
# 4  db-scan-blob-storage  2026-02-27-ABCDEF

# %%
traditional_df = db_context.execute(f"SELECT * FROM read_parquet('{hive_path_traditional}')").fetchdf()
print("Shape:", traditional_df.shape)
traditional_df.head()
# Out:
# Shape: (3172, 16)
#    elapsed_time  delta_time  delta_process_cpu_time  process_cpu_percentage  \
# 0      0.009951    0.009951                     0.0                     0.0
# 1      0.025168    0.015218                     0.0                     0.0
# 2      0.039818    0.014649                     0.0                     0.0
# 3      0.055831    0.016014                     0.0                     0.0
# 4      0.070587    0.014756                     0.0                     0.0
#
#          rss                                             core_1  \
# 0  181366784  {'idle': 0.015625, 'iowait': 0.0, 'percent': 0...
# 1  181366784  {'idle': 0.015625, 'iowait': 0.0, 'percent': 1...
# 2  181370880  {'idle': 0.03125, 'iowait': 0.0, 'percent': 0....
# 3  181370880  {'idle': 0.046875, 'iowait': 0.0, 'percent': 0...
# 4  181370880  {'idle': 0.046875, 'iowait': 0.0, 'percent': 1...
#
#                                               core_2  \
# 0  {'idle': 0.015625, 'iowait': 0.0, 'percent': 0...
# 1  {'idle': 0.03125, 'iowait': 0.0, 'percent': 0....
# 2  {'idle': 0.046875, 'iowait': 0.0, 'percent': 0...
# 3  {'idle': 0.0625, 'iowait': 0.0, 'percent': 0.0...
# 4  {'idle': 0.0625, 'iowait': 0.0, 'percent': 100...
#
#                                               core_3  \
# 0  {'idle': 0.015625, 'iowait': 0.0, 'percent': 0...
# 1  {'idle': 0.03125, 'iowait': 0.0, 'percent': 0....
# 2  {'idle': 0.046875, 'iowait': 0.0, 'percent': 0...
# 3  {'idle': 0.0625, 'iowait': 0.0, 'percent': 0.0...
# 4  {'idle': 0.0625, 'iowait': 0.0, 'percent': 100...
#
#                                               core_4  \
# 0  {'idle': 0.015625, 'iowait': 0.0, 'percent': 0...
# 1  {'idle': 0.03125, 'iowait': 0.0, 'percent': 0....
# 2  {'idle': 0.046875, 'iowait': 0.0, 'percent': 0...
# 3  {'idle': 0.0625, 'iowait': 0.0, 'percent': 0.0...
# 4  {'idle': 0.0625, 'iowait': 0.0, 'percent': 100...
#
#                                               core_5  \
# 0  {'idle': 0.015625, 'iowait': 0.0, 'percent': 0...
# 1  {'idle': 0.03125, 'iowait': 0.0, 'percent': 0....
# 2  {'idle': 0.046875, 'iowait': 0.0, 'percent': 0...
# 3  {'idle': 0.0625, 'iowait': 0.0, 'percent': 0.0...
# 4  {'idle': 0.0625, 'iowait': 0.0, 'percent': 100...
#
#                                               core_6  \
# 0  {'idle': 0.0, 'iowait': 0.0, 'percent': 100.0,...
# 1  {'idle': 0.015625, 'iowait': 0.0, 'percent': 0...
# 2  {'idle': 0.03125, 'iowait': 0.0, 'percent': 0....
# 3  {'idle': 0.046875, 'iowait': 0.0, 'percent': 0...
# 4  {'idle': 0.046875, 'iowait': 0.0, 'percent': 0...
#
#                                               core_7  \
# 0  {'idle': 0.015625, 'iowait': 0.0, 'percent': 0...
# 1  {'idle': 0.03125, 'iowait': 0.0, 'percent': 0....
# 2  {'idle': 0.046875, 'iowait': 0.0, 'percent': 0...
# 3  {'idle': 0.0625, 'iowait': 0.0, 'percent': 0.0...
# 4  {'idle': 0.0625, 'iowait': 0.0, 'percent': 100...
#
#                                               core_8  iteration  \
# 0  {'idle': 0.015625, 'iowait': 0.0, 'percent': 0...          1
# 1  {'idle': 0.03125, 'iowait': 0.0, 'percent': 0....          1
# 2  {'idle': 0.046875, 'iowait': 0.0, 'percent': 0...          1
# 3  {'idle': 0.0625, 'iowait': 0.0, 'percent': 0.0...          1
# 4  {'idle': 0.0625, 'iowait': 0.0, 'percent': 100...          1
#
#           query_id             run_id
# 0  db-scan-postgis  2026-02-27-ABCDEF
# 1  db-scan-postgis  2026-02-27-ABCDEF
# 2  db-scan-postgis  2026-02-27-ABCDEF
# 3  db-scan-postgis  2026-02-27-ABCDEF
# 4  db-scan-postgis  2026-02-27-ABCDEF

# %% [markdown]
# ## Preprocessing

# %%
cn_dfs = {}
for iteration, group in cn_df.groupby("iteration"):
    group = group.copy()
    group["rss_bytes"] = group["rss"]
    group["rss"] = bytes_to_mb(group["rss_bytes"])
    cn_dfs[iteration] = group

traditional_dfs = {}
for iteration, group in traditional_df.groupby("iteration"):
    group = group.copy()
    group["rss_bytes"] = group["rss"]
    group["rss"] = bytes_to_mb(group["rss_bytes"])
    traditional_dfs[iteration] = group

# %% [markdown]
# ## Shapiro–Wilk normality test for Query A and Query B
#
# The Shapiro–Wilk test is used to check whether the performance data for each query follows a normal (Gaussian) distribution. This is important because it determines which statistical tests are appropriate in later analysis.
#
# The test is run separately for Query A and Query B.
# A **p-value > 0.05** means the data does **not significantly deviate from normality**, while a **p-value ≤ 0.05** indicates that the data is **not normally distributed**.
#
# Interpreting the results:
# - If **both** Query A and Query B have p > 0.05 → the data is approximately normal, and parametric tests (like the t-test) can be used.
# - If **either** query has p ≤ 0.05 → the data is non-normal, and non-parametric tests (such as Mann–Whitney U) should be used instead.
#
# The Shapiro–Wilk test therefore serves as the first step in selecting the correct statistical method for comparing the performance of the two queries.

# %%
shapiro_wilk(dict_a=traditional_dfs, dict_b=cn_dfs, parameter="elapsed_time")
shapiro_wilk(dict_a=traditional_dfs, dict_b=cn_dfs, parameter="process_cpu_percentage")
shapiro_wilk(dict_a=traditional_dfs, dict_b=cn_dfs, parameter="rss")
# Out:
# Shapiro–Wilk test for 'elapsed_time':
# A: stat=0.8339376, p=0.0000000
# B: stat=0.3543381, p=0.0000000
# 	-> Query A: Data is NOT normally distributed (p=0.0000000 ≤ 0.05)
# 	-> Query B: Data is NOT normally distributed (p=0.0000000 ≤ 0.05)
#
#
# Shapiro–Wilk test for 'process_cpu_percentage':
# A: stat=0.4207837, p=0.0000000
# B: stat=0.8767064, p=0.0000001
# 	-> Query A: Data is NOT normally distributed (p=0.0000000 ≤ 0.05)
# 	-> Query B: Data is NOT normally distributed (p=0.0000001 ≤ 0.05)
#
#
# Shapiro–Wilk test for 'rss':
# A: stat=0.2891604, p=0.0000000
# B: stat=0.7979865, p=0.0000000
# 	-> Query A: Data is NOT normally distributed (p=0.0000000 ≤ 0.05)
# 	-> Query B: Data is NOT normally distributed (p=0.0000000 ≤ 0.05)

# %% [markdown]
# ## Mann–Whitney U and Cliff’s Delta tests for comparing Query A and Query B
#
# The Mann–Whitney U test is a non-parametric test used when the data is not normally distributed. It evaluates whether Query A and Query B come from the same distribution for a given performance metric (e.g., runtime, CPU usage, RAM). A p-value ≤ 0.05 indicates a statistically significant difference between the queries.
#
# Cliff’s delta measures the **direction** and **magnitude** of that difference. It ranges from −1 to +1:
#
# - Values near **0** → negligible difference.
# - Values near **+1** → Query A’s values are almost always **higher** than Query B’s.
# - Values near **−1** → Query A’s values are almost always **lower** than Query B’s.
#
# Interpretation depends on the metric:
# - **Runtime**: delta near −1 → Query A is consistently faster; delta near +1 → Query A is slower.
# - **CPU/RAM**: delta near −1 → Query A uses less resources; delta near +1 → Query A uses more.
#
# Together, the U test tells you *whether* the queries differ, and Cliff’s delta tells you *how much* and *in which direction*.

# %%
mann_whitney_u_test(dict_a=traditional_dfs, dict_b=cn_dfs, parameter="elapsed_time")
mann_whitney_u_test(dict_a=traditional_dfs, dict_b=cn_dfs, parameter="process_cpu_percentage")
mann_whitney_u_test(dict_a=traditional_dfs, dict_b=cn_dfs, parameter="rss")
# Out:
# Mann–Whitney U test for 'elapsed_time':
# U-statistic=10000.0000000, p=0.0000000
# Cliff's delta=1.0000000
# 	-> Significant difference (p=0.0000000 ≤ 0.05)
# 	-> Effect size: large (|δ|=1.0000000)
#
#
# Mann–Whitney U test for 'process_cpu_percentage':
# U-statistic=634.5000000, p=0.0000000
# Cliff's delta=-0.8731000
# 	-> Significant difference (p=0.0000000 ≤ 0.05)
# 	-> Effect size: large (|δ|=0.8731000)
#
#
# Mann–Whitney U test for 'rss':
# U-statistic=0.0000000, p=0.0000000
# Cliff's delta=-1.0000000
# 	-> Significant difference (p=0.0000000 ≤ 0.05)
# 	-> Effect size: large (|δ|=1.0000000)

# %% [markdown]
# ## Maximum `wall_clock_time`, `cpu_percentage` and `rss` over all iterations
#
# We are interested in the maximum value of each performance metric (e.g., runtime, CPU usage, RAM usage) because this represents the **peak resource requirement** during a run. In benchmarking and capacity planning, the maximum value is often more important than the mean or median, since peak consumption determines the minimum resources that must be allocated for the query to run reliably.

# %%
linechart(
    dict_a=traditional_dfs,
    dict_b=cn_dfs,
    parameter="elapsed_time",
    label_a="PostGIS",
    label_b="Blob Storage w/ DuckDB"
)

# %%
linechart(
    dict_a=traditional_dfs,
    dict_b=cn_dfs,
    parameter="process_cpu_percentage",
    label_a="PostGIS",
    label_b="Blob Storage w/ DuckDB"
)

# %%
linechart(
    dict_a=traditional_dfs,
    dict_b=cn_dfs,
    parameter="rss",
    label_a="PostGIS",
    label_b="Blob Storage w/ DuckDB"
)

# %% [markdown]
# ## Inspect specific iterations

# %%
iterations = [1, 8, 40, 77, 79, 90]

# %%
linechart_per_iteration(
    dict_a=traditional_dfs,
    dict_b=cn_dfs,
    parameter="process_cpu_percentage",
    iterations=iterations,
    label_a="PostGIS",
    label_b="Blob Storage w/ DuckDB",
    share_y=False
)

# %%
linechart_per_iteration(
    dict_a=traditional_dfs,
    dict_b=cn_dfs,
    parameter="rss",
    iterations=iterations,
    label_a="PostGIS",
    label_b="Blob Storage w/ DuckDB",
    share_y=False
)

# %%
linechart_per_iteration_timeseries(
    dict_a=traditional_dfs,
    dict_b=cn_dfs,
    parameter="process_cpu_percentage",
    iterations=iterations,
    label_a="PostGIS",
    label_b="Blob Storage w/ DuckDB"
)

# %%
linechart_per_iteration_timeseries(
    dict_a=traditional_dfs,
    dict_b=cn_dfs,
    parameter="rss",
    iterations=iterations,
    label_a="PostGIS",
    label_b="Blob Storage w/ DuckDB"
)

# %% [markdown]
# ## System CPU-times for each core
# Plotting the maxiumum `system`, `user`, `iowait` and `idle` CPU times for the system for each core

# %%
plot_barchart_per_core(
    dict_a=traditional_dfs,
    dict_b=cn_dfs,
    label_a="PostGIS",
    label_b="Blob Storage w/ DuckDB",
    title="CPU time (s) per core"
)

# %%
heatmap_cpu_percent_per_iteration(
    dict_a=traditional_dfs,
    dict_b=cn_dfs,
    iterations=iterations,
    label_a="PostGIS",
    label_b="Blob Storage w/ DuckDB",
)
